# %%
import pandas as pd
import numpy as numpy

# %%
data_jee = pd.read_excel("JEE_Score.xlsx","Sheet1")

# %%
data_jee
# Out:
#     Boards_10  Maths_10  Science_10  Mock_JEE_1  Mock_JEE_2  Mock_JEE_3  \
# 0        84.4      93.0        84.0        94.0       87.67        56.0
# 1        92.8      93.0        93.0         0.0        0.00         0.0
# 2        84.0      93.0        94.0        50.0       40.00        40.0
# 3        89.8      85.0        95.0         0.0        0.00         0.0
# 4        69.0      81.0        64.0        89.0       82.00        82.0
# ..        ...       ...         ...         ...         ...         ...
# 82        NaN       NaN         NaN         NaN         NaN         NaN
# 83        NaN       NaN         NaN         NaN         NaN         NaN
# 84        NaN       NaN         NaN         NaN         NaN         NaN
# 85        NaN       NaN         NaN         NaN         NaN         NaN
# 86        NaN       NaN         NaN         NaN         NaN         NaN
#
#     Boards_12  study_hours  Final_JEE
# 0       79.23          4.0       99.0
# ...

# %%
data_jee=data_jee.iloc[:60,1:]

# %%
data_jee
# Out:
#     Maths_10  Science_10  Mock_JEE_1  Mock_JEE_2  Mock_JEE_3  Boards_12  \
# 0       93.0        84.0       94.00       87.67       56.00     79.230
# 1       93.0        93.0        0.00        0.00        0.00     71.000
# 2       93.0        94.0       50.00       40.00       40.00     75.000
# 3       85.0        95.0        0.00        0.00        0.00     68.770
# 4       81.0        64.0       89.00       82.00       82.00     83.000
# 5       82.0        71.0        0.00        0.00        0.00     86.830
# 6       90.0        73.0       71.00       73.00       56.00     84.000
# 7       89.0        88.0       78.00       98.00       79.00     90.000
# 8      100.0        95.0       72.00       94.00       94.00     94.000
# 9       95.0        87.0        0.00        0.00        0.00     89.670
# 10      95.0        92.0       70.00       65.00       65.00     74.000
# 11      96.0        91.0       70.00       60.00       70.00     83.000
# ...

# %%
(i,j) = data_jee.shape
for k in range(i):
    for l in range(j-3):
        if data_jee.iloc[k][l]<1:
            data_jee.iloc[k][l]*=100

# %%
data_jee
# Out:
#     Maths_10  Science_10  Mock_JEE_1  Mock_JEE_2  Mock_JEE_3  Boards_12  \
# 0       93.0        84.0       94.00       87.67       56.00     79.230
# 1       93.0        93.0        0.00        0.00        0.00     71.000
# 2       93.0        94.0       50.00       40.00       40.00     75.000
# 3       85.0        95.0        0.00        0.00        0.00     68.770
# 4       81.0        64.0       89.00       82.00       82.00     83.000
# 5       82.0        71.0        0.00        0.00        0.00     86.830
# 6       90.0        73.0       71.00       73.00       56.00     84.000
# 7       89.0        88.0       78.00       98.00       79.00     90.000
# 8      100.0        95.0       72.00       94.00       94.00     94.000
# 9       95.0        87.0        0.00        0.00        0.00     89.670
# 10      95.0        92.0       70.00       65.00       65.00     74.000
# 11      96.0        91.0       70.00       60.00       70.00     83.000
# ...

# %%
data_jee.shape
# Out:
# (60, 8)

# %%
(i,j) = data_jee.shape

# %%
count =0
l=[]
for i in range(60):
    if data_jee.iloc[i][2]== data_jee.iloc[i][3]== data_jee.iloc[i][4]==0:
        count+=1
        l.append(i)

# %%
count
# Out:
# 24

# %%
data_jee.shape
# Out:
# (60, 8)

# %%
l
# Out:
# [1,
#  3,
#  5,
#  9,
#  17,
#  21,
#  23,
#  25,
#  27,
#  29,
#  30,
#  33,
#  36,
#  38,
#  40,
#  43,
#  44,
#  46,
#  51,
#  52,
#  54,
#  55,
#  56,
#  58]

# %%
data_jee=data_jee.drop(l)

# %%
data_jee.shape
# Out:
# (36, 8)

# %%
data_jee
# Out:
#     Maths_10  Science_10  Mock_JEE_1  Mock_JEE_2  Mock_JEE_3  Boards_12  \
# 0       93.0        84.0       94.00       87.67       56.00      79.23
# 2       93.0        94.0       50.00       40.00       40.00      75.00
# 4       81.0        64.0       89.00       82.00       82.00      83.00
# 6       90.0        73.0       71.00       73.00       56.00      84.00
# 7       89.0        88.0       78.00       98.00       79.00      90.00
# 8      100.0        95.0       72.00       94.00       94.00      94.00
# 10      95.0        92.0       70.00       65.00       65.00      74.00
# 11      96.0        91.0       70.00       60.00       70.00      83.00
# 12      75.0        56.0       65.00       55.00       70.00      72.92
# 13      84.0        67.0       57.00        0.00       70.00      74.00
# 14      99.0        97.0        0.00        0.00      110.00      81.69
# 15      99.0        85.0       74.00       67.00       67.00      76.00
# ...

# %%
count =0
l=[]
for i in range(36):
    if data_jee.iloc[i][2]== data_jee.iloc[i][3]==0 or data_jee.iloc[i][3] == data_jee.iloc[i][4]==0 or data_jee.iloc[i][2]== data_jee.iloc[i][4]==0:
        count+=1
        data_jee=data_jee.drop(l)

# %%
l
# Out:
# []

# %%
data_jee
# Out:
#     Maths_10  Science_10  Mock_JEE_1  Mock_JEE_2  Mock_JEE_3  Boards_12  \
# 0       93.0        84.0       94.00       87.67       56.00      79.23
# 2       93.0        94.0       50.00       40.00       40.00      75.00
# 4       81.0        64.0       89.00       82.00       82.00      83.00
# 6       90.0        73.0       71.00       73.00       56.00      84.00
# 7       89.0        88.0       78.00       98.00       79.00      90.00
# 8      100.0        95.0       72.00       94.00       94.00      94.00
# 10      95.0        92.0       70.00       65.00       65.00      74.00
# 11      96.0        91.0       70.00       60.00       70.00      83.00
# 12      75.0        56.0       65.00       55.00       70.00      72.92
# 13      84.0        67.0       57.00        0.00       70.00      74.00
# 14      99.0        97.0        0.00        0.00      110.00      81.69
# 15      99.0        85.0       74.00       67.00       67.00      76.00
# ...

# %%
X = data_jee.drop('Final_JEE', axis=1)
y = data_jee['Final_JEE']

# %%
X
# Out:
#     Maths_10  Science_10  Mock_JEE_1  Mock_JEE_2  Mock_JEE_3  Boards_12  \
# 0       93.0        84.0       94.00       87.67       56.00      79.23
# 2       93.0        94.0       50.00       40.00       40.00      75.00
# 4       81.0        64.0       89.00       82.00       82.00      83.00
# 6       90.0        73.0       71.00       73.00       56.00      84.00
# 7       89.0        88.0       78.00       98.00       79.00      90.00
# 8      100.0        95.0       72.00       94.00       94.00      94.00
# 10      95.0        92.0       70.00       65.00       65.00      74.00
# 11      96.0        91.0       70.00       60.00       70.00      83.00
# 12      75.0        56.0       65.00       55.00       70.00      72.92
# 13      84.0        67.0       57.00        0.00       70.00      74.00
# 14      99.0        97.0        0.00        0.00      110.00      81.69
# 15      99.0        85.0       74.00       67.00       67.00      76.00
# ...

# %%
y
# Out:
# 0     99.0000
# 2     25.0000
# 4     20.0000
# 6     65.0000
# 7     75.0000
# 8     64.0000
# 10    60.0000
# 11    93.0000
# 12    60.0000
# 13     0.0000
# 14    92.3800
# 15    56.0000
# 16    40.0000
# 18    66.6200
# 19    80.0000
# 20    60.0000
# 22    60.7800
# 24    27.0000
# 26    65.0000
# 28    60.0000
# 31    67.0500
# 32    99.0000
# 34    80.0000
# 35    88.0000
# 37    79.0000
# 39    19.0000
# 41    80.0000
# 42    60.0000
# 45    60.0000
# 47    61.6600
# 48    52.8728
# 49    49.8669
# 50    61.0000
# 53     0.0000
# 57    60.0000
# 59    78.0000
# Name: Final_JEE, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
y_train
# Out:
# 12    60.00
# 24    27.00
# 13     0.00
# 57    60.00
# 0     99.00
# 7     75.00
# 47    61.66
# 20    60.00
# 28    60.00
# 8     64.00
# 15    56.00
# 2     25.00
# 37    79.00
# 4     20.00
# 53     0.00
# 6     65.00
# 50    61.00
# 35    88.00
# 42    60.00
# 14    92.38
# 34    80.00
# 26    65.00
# 39    19.00
# 10    60.00
# 31    67.05
# 11    93.00
# 19    80.00
# 45    60.00
# Name: Final_JEE, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)

svm = SVR()
svm.fit(X_train,y_train)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

gr = GradientBoostingRegressor()
gr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = rf.predict(X_test)
y_pred4 = gr.predict(X_test)

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)

# %%
print(score1,score2,score3,score4)
# Out:
# 0.2641310187428213 -0.00591383202724427 -0.11235951206064998 -0.03635461060845491

# %%
y_pred1
# Out:
# array([74.26193316, 70.47715287, 81.09516791, 48.05934353, 52.77889518,
#        72.9406735 , 91.84527558, 74.44968904])

# %%
gr.predict([[90,72,50,70,90,70,8]])
# Out:
# array([72.59184204])

# %% [markdown]
# # Saving Model

# %%
import joblib

# %%
joblib.dump(gr, 'filename.pkl')
# Out:
# ['filename.pkl']

# %%
gr_from_joblib = joblib.load('filename.pkl')

# %%
gr_from_joblib.predict(X_test)
# Out:
# array([61.95554702, 69.96057846, 60.34340953, 62.2697223 , 64.57446299,
#        78.87306122, 74.9619919 , 61.94416695])
