# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_cet = pd.read_excel("CET_Score.xlsx","Sheet2")

# %%
data_cet
# Out:
#     Boards_10  Maths_10  Science_10  Mock_CET_1  Mock_CET_2  Mock_CET_3  \
# 0        84.4      93.0        84.0        90.0        87.4        99.0
# 1        92.8      93.0        93.0        73.0        73.0        74.0
# 2        84.0      93.0        94.0        60.0        50.0        50.0
# 3        89.8      85.0        95.0         0.0         0.0         0.0
# 4        69.0      81.0        64.0        64.0        76.0        72.0
# ..        ...       ...         ...         ...         ...         ...
# 82        NaN       NaN         NaN         NaN         NaN         NaN
# 83        NaN       NaN         NaN         NaN         NaN         NaN
# 84        NaN       NaN         NaN         NaN         NaN         NaN
# 85        NaN       NaN         NaN         NaN         NaN         NaN
# 86        NaN       NaN         NaN         NaN         NaN         NaN
#
#     Boards_12  study_hours  Final_CET
# 0       79.23          4.0      87.50
# ...

# %%
data_cet=data_cet.iloc[:60,1:]

# %%
data_cet
# Out:
#     Maths_10  Science_10  Mock_CET_1  Mock_CET_2  Mock_CET_3  Boards_12  \
# 0       93.0        84.0      90.000       87.40       99.00     79.230
# 1       93.0        93.0      73.000       73.00       74.00     71.000
# 2       93.0        94.0      60.000       50.00       50.00     75.000
# 3       85.0        95.0       0.000        0.00        0.00     68.770
# 4       81.0        64.0      64.000       76.00       72.00     83.000
# 5       82.0        71.0       0.000        0.00        0.00     86.830
# 6       90.0        73.0      78.000       62.00       82.00     84.000
# 7       89.0        88.0     120.000      125.00      125.00     90.000
# 8      100.0        95.0      72.000       94.00       94.00     94.000
# 9       95.0        87.0       0.000        0.00        0.00     89.670
# 10      95.0        92.0     124.000      134.00      120.00     74.000
# 11      96.0        91.0      70.000       60.00       70.00     83.000
# ...

# %%
data_cet.head()
# Out:
#    Maths_10  Science_10  Mock_CET_1  Mock_CET_2  Mock_CET_3  Boards_12  \
# 0      93.0        84.0        90.0        87.4        99.0      79.23
# 1      93.0        93.0        73.0        73.0        74.0      71.00
# 2      93.0        94.0        60.0        50.0        50.0      75.00
# 3      85.0        95.0         0.0         0.0         0.0      68.77
# 4      81.0        64.0        64.0        76.0        72.0      83.00
#
#    study_hours  Final_CET
# 0          4.0      87.50
# 1          6.0      75.00
# 2          1.0      93.00
# 3         11.0      85.67
# 4          6.0      83.00

# %%
(i,j) = data_cet.shape
for k in range(i):
    for l in range(j-3):
        if data_cet.iloc[k][l]<1:
            data_cet.iloc[k][l]*=100

# %%
data_cet
# Out:
#     Maths_10  Science_10  Mock_CET_1  Mock_CET_2  Mock_CET_3  Boards_12  \
# 0       93.0        84.0       90.00       87.40       99.00     79.230
# 1       93.0        93.0       73.00       73.00       74.00     71.000
# 2       93.0        94.0       60.00       50.00       50.00     75.000
# 3       85.0        95.0        0.00        0.00        0.00     68.770
# 4       81.0        64.0       64.00       76.00       72.00     83.000
# 5       82.0        71.0        0.00        0.00        0.00     86.830
# 6       90.0        73.0       78.00       62.00       82.00     84.000
# 7       89.0        88.0      120.00      125.00      125.00     90.000
# 8      100.0        95.0       72.00       94.00       94.00     94.000
# 9       95.0        87.0        0.00        0.00        0.00     89.670
# 10      95.0        92.0      124.00      134.00      120.00     74.000
# 11      96.0        91.0       70.00       60.00       70.00     83.000
# ...

# %%
data_cet.shape
# Out:
# (60, 8)

# %%
(i,j) = data_cet.shape

# %%
count =0
l=[]
for i in range(60):
    if data_cet.iloc[i][2]== data_cet.iloc[i][3]== data_cet.iloc[i][4]==0:
        count+=1
        l.append(i)

# %%
count
# Out:
# 15

# %%
data_cet.shape
# Out:
# (60, 8)

# %%
l
# Out:
# [3, 5, 9, 17, 29, 30, 33, 36, 38, 41, 46, 52, 55, 56, 58]

# %%
data_cet=data_cet.drop(l)

# %%
data_cet.shape
# Out:
# (45, 8)

# %%
data_cet
# Out:
#     Maths_10  Science_10  Mock_CET_1  Mock_CET_2  Mock_CET_3  Boards_12  \
# 0       93.0        84.0       90.00       87.40       99.00     79.230
# 1       93.0        93.0       73.00       73.00       74.00     71.000
# 2       93.0        94.0       60.00       50.00       50.00     75.000
# 4       81.0        64.0       64.00       76.00       72.00     83.000
# 6       90.0        73.0       78.00       62.00       82.00     84.000
# 7       89.0        88.0      120.00      125.00      125.00     90.000
# 8      100.0        95.0       72.00       94.00       94.00     94.000
# 10      95.0        92.0      124.00      134.00      120.00     74.000
# 11      96.0        91.0       70.00       60.00       70.00     83.000
# 12      75.0        56.0       60.00       70.00       65.00     72.920
# 13      84.0        67.0       57.00       70.00       70.00     74.000
# 14      99.0        97.0       85.00       95.00      100.00     81.690
# ...

# %%
count =0
l=[]
for i in range(45):
    if data_cet.iloc[i][2]== data_cet.iloc[i][3]==0 or data_cet.iloc[i][3] == data_cet.iloc[i][4]==0 or data_cet.iloc[i][2]== data_cet.iloc[i][4]==0:
        count+=1
        data_cet=data_cet.drop(l)

# %%
l
# Out:
# []

# %%
data_cet
# Out:
#     Maths_10  Science_10  Mock_CET_1  Mock_CET_2  Mock_CET_3  Boards_12  \
# 0       93.0        84.0       90.00       87.40       99.00     79.230
# 1       93.0        93.0       73.00       73.00       74.00     71.000
# 2       93.0        94.0       60.00       50.00       50.00     75.000
# 4       81.0        64.0       64.00       76.00       72.00     83.000
# 6       90.0        73.0       78.00       62.00       82.00     84.000
# 7       89.0        88.0      120.00      125.00      125.00     90.000
# 8      100.0        95.0       72.00       94.00       94.00     94.000
# 10      95.0        92.0      124.00      134.00      120.00     74.000
# 11      96.0        91.0       70.00       60.00       70.00     83.000
# 12      75.0        56.0       60.00       70.00       65.00     72.920
# 13      84.0        67.0       57.00       70.00       70.00     74.000
# 14      99.0        97.0       85.00       95.00      100.00     81.690
# ...

# %%
data_cet
# Out:
#     Maths_10  Science_10  Mock_CET_1  Mock_CET_2  Mock_CET_3  Boards_12  \
# 0       93.0        84.0       90.00       87.40       99.00     79.230
# 1       93.0        93.0       73.00       73.00       74.00     71.000
# 2       93.0        94.0       60.00       50.00       50.00     75.000
# 4       81.0        64.0       64.00       76.00       72.00     83.000
# 6       90.0        73.0       78.00       62.00       82.00     84.000
# 7       89.0        88.0      120.00      125.00      125.00     90.000
# 8      100.0        95.0       72.00       94.00       94.00     94.000
# 10      95.0        92.0      124.00      134.00      120.00     74.000
# 11      96.0        91.0       70.00       60.00       70.00     83.000
# 12      75.0        56.0       60.00       70.00       65.00     72.920
# 13      84.0        67.0       57.00       70.00       70.00     74.000
# 14      99.0        97.0       85.00       95.00      100.00     81.690
# ...

# %%
#data_cet['total_score']= data_cet['Maths_10'] + data_cet['Science_10'] + data_cet['Mock_CET_1'] + data_cet['Mock_CET_2'] + data_cet['Mock_CET_3'] + data_cet['Boards_12']

# %%
#data_cet.head()

# %%
#sns.scatterplot(data = data_cet,x='total_score',y='Final_CET')

# %%
X = data_cet.drop('Final_CET', axis=1)
y = data_cet['Final_CET']

# %%
X
# Out:
#     Maths_10  Science_10  Mock_CET_1  Mock_CET_2  Mock_CET_3  Boards_12  \
# 0       93.0        84.0       90.00       87.40       99.00     79.230
# 1       93.0        93.0       73.00       73.00       74.00     71.000
# 2       93.0        94.0       60.00       50.00       50.00     75.000
# 4       81.0        64.0       64.00       76.00       72.00     83.000
# 6       90.0        73.0       78.00       62.00       82.00     84.000
# 7       89.0        88.0      120.00      125.00      125.00     90.000
# 8      100.0        95.0       72.00       94.00       94.00     94.000
# 10      95.0        92.0      124.00      134.00      120.00     74.000
# 11      96.0        91.0       70.00       60.00       70.00     83.000
# 12      75.0        56.0       60.00       70.00       65.00     72.920
# 13      84.0        67.0       57.00       70.00       70.00     74.000
# 14      99.0        97.0       85.00       95.00      100.00     81.690
# ...

# %%
y
# Out:
# 0      87.5000
# 1      75.0000
# 2      93.0000
# 4      83.0000
# 6      85.0000
# 7      76.3300
# 8      74.0000
# 10     70.0000
# 11     90.0000
# 12     36.0000
# 13     70.0000
# 14    117.0000
# 15     91.6300
# 16     84.2600
# 18     88.6400
# 19     80.0000
# 20     78.0000
# 21     65.0000
# 22     77.8700
# 23     80.0000
# 24     27.0000
# 25     60.4500
# 26     69.0000
# 27     73.0000
# 28     76.6660
# 31     88.7100
# 32     99.0000
# 34     88.0000
# 35     98.0000
# 37     83.0000
# 39     83.0000
# 40     92.0500
# 42     74.6600
# 43     48.0000
# 44     65.0000
# 45     60.0000
# 47     87.9600
# 48     56.6300
# 49     78.8965
# 50     75.0000
# 51      0.8000
# 53     95.0000
# 54     88.2700
# 57     70.0000
# 59     62.0000
# Name: Final_CET, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
y_train
# Out:
# 4      83.0000
# 8      74.0000
# 28     76.6660
# 42     74.6600
# 23     80.0000
# 21     65.0000
# 16     84.2600
# 54     88.2700
# 19     80.0000
# 12     36.0000
# 20     78.0000
# 48     56.6300
# 40     92.0500
# 34     88.0000
# 0      87.5000
# 39     83.0000
# 37     83.0000
# 7      76.3300
# 14    117.0000
# 43     48.0000
# 1      75.0000
# 51      0.8000
# 25     60.4500
# 2      93.0000
# 44     65.0000
# 27     73.0000
# 47     87.9600
# 13     70.0000
# 26     69.0000
# 22     77.8700
# 59     62.0000
# 24     27.0000
# 10     70.0000
# 18     88.6400
# 35     98.0000
# 49     78.8965
# Name: Final_CET, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)

svm = SVR()
svm.fit(X_train,y_train)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

gr = GradientBoostingRegressor()
gr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = rf.predict(X_test)
y_pred4 = gr.predict(X_test)

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)

# %%
print(score1,score2,score3,score4)
# Out:
# -0.7521737591938606 -0.1643695990068359 -0.8906381523532283 -0.15704971466979978

# %%
final_data = pd.DataFrame({'Models':['LR','SVR','RF','GR'],
                          'R2_SCORE':[score1,score2,score3,score4]})

# %%
final_data
# Out:
#   Models  R2_SCORE
# 0     LR -0.752174
# 1    SVR -0.164370
# 2     RF -0.890638
# 3     GR -0.157050

# %%
sns.barplot(final_data['R2_SCORE'],final_data['Models'])
# Out:
# D:\ANAKONDA\INSTALLATION\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='R2_SCORE', ylabel='Models'>

# %%
y_pred1
# Out:
# array([94.82018874, 89.69660777, 78.49211005, 90.00263351, 63.71761432,
#        65.0073451 , 78.79700022, 80.73215472, 85.4267741 ])

# %%
y_pred2
# Out:
# array([78.99166084, 78.8878967 , 78.84780192, 78.4788345 , 76.9305877 ,
#        77.47342846, 78.37282612, 78.70166807, 78.28994881])

# %%
y_pred3
# Out:
# array([83.253525, 85.30795 , 89.22082 , 89.1101  , 51.83606 , 56.5896  ,
#        81.538145, 78.910985, 74.76945 ])

# %%
y_pred4
# Out:
# array([79.80774483, 86.42544343, 91.55740478, 86.9161651 , 50.67407705,
#        73.96926133, 81.72303891, 72.32108361, 74.50590016])

# %%
y_test
# Out:
# 50    75.00
# 31    88.71
# 32    99.00
# 57    70.00
# 45    60.00
# 53    95.00
# 6     85.00
# 15    91.63
# 11    90.00
# Name: Final_CET, dtype: float64

# %%
gr.predict([[80,79,86,70,80,72,5]])
# Out:
# array([50.52432139])

# %% [markdown]
# ### Saving model

# %%
import pickle

# %%
filename= 'model.pkl'

# %%
pickle.dump(gr, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_test, y_test)
print(result)
# Out:
# -0.15704971466979978
